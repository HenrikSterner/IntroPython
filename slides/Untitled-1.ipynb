# %%
import networkx as nx


# Visualize a weighted graph
G = nx.Graph()
G.add_edge(1, 2, weight=4)
G.add_edge(2, 3, weight=2)
G.add_edge(3, 4, weight=1)
G.add_edge(4, 1, weight=3)
G.add_edge(1, 5, weight=5)

nx.draw(G, with_labels=True)
nx.draw_networkx_edge_labels(G, pos=nx.spring_layout(G), edge_labels={(u, v): d['weight'] for u, v, d in G.edges(data=True)})
# Out:
# {(1, 2): Text(0.1266603234715108, -0.172974875530998, '4'),
#  (1, 4): Text(0.008668878871418234, 0.2815382913615679, '3'),
#  (1, 5): Text(0.6789107096917313, 0.18574108368210934, '5'),
#  (2, 3): Text(-0.5086688788714183, -0.41420865671382845, '2'),
#  (3, 4): Text(-0.6266603234715108, 0.04030451017873743, '1')}

# %%
graph = {
    0: [(1, 1)],
    1: [(0, 1), (2, 1), (3, 1)],
    2: [(1, 1)],
    3: [(1, 1)]
}

# visualisering af grafen
G = nx.Graph(graph)
nx.draw(G, with_labels=True)
plt.show()

dist = dijkstra(graph, 0)
print(dist)
# Out:
# [0, 1, 2, 2]
